# %%
import pandas as pd 
import numpy as np

df=pd.read_csv("data.csv")
data=df["Calories"]


mean=np.mean(data)
median=np.median(data)
mode=data.mode()[0]
variance=np.var(data)
std_deviation=np.std(data)

print("Mean:",mean)
print("Median:",median)
print("Mode:",mode)
print("Variance:",variance)
print("Standard Deviation:",std_deviation)
# Out:
# Mean: 375.79024390243904
# Median: nan
# Mode: 300.0
# Variance: 70525.58905116003
# Standard Deviation: 265.5665435463587
