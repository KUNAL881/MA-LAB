# %%
import numpy as np

generator_matrix = np.array([[0.1, -0.05, 0.0],
                              [-0.05, 0.15, -0.1],
                              [0.0, -0.1, 0.1]], dtype=float)

ohm_matrix = np.array([[10.0, -5.0, 0.0],
                        [-5.0, 15.0, -10.0],
                        [0.0, -10.0, 10.0]], dtype=float)

print(generator_matrix)
print(ohm_matrix)
