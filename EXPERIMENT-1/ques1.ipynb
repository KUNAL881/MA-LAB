# %%
import math as mt

print(mt.floor(3.7))     # Floor value
print(mt.ceil(3.3))      # Ceil value
print(mt.sqrt(16))       # Square root
print(mt.isqrt(64))      # Integer square root
print(mt.gcd(48, 18))    # Greatest common divisor
print(mt.comb(4, 5))     # Combination (if required)
